# %%
import pandas as pd

# %%
df  =  pd.read_csv("full.csv")
# Out:
# /var/folders/xp/6bbyd7cd5k39n1yq5vbrzgvr0000gn/T/ipykernel_45941/2342406190.py:1: DtypeWarning: Columns (29,30,31,61,79,80,81,82,106,110,119) have mixed types. Specify dtype option on import or set low_memory=False.
#   df  =  pd.read_csv("full.csv")

# %%
df
# Out:
#              id         Available as of                Available date
# 0      10572904  After signing the deed  September 30 2023 - 12:00 AM  \
# 1      10572903  After signing the deed  September 30 2023 - 12:00 AM
# 2      10572509  After signing the deed      August 6 2023 - 12:00 AM
# 3      10572508  After signing the deed  September 30 2023 - 12:00 AM
# 4      10572922           To be defined                           NaN
# ...         ...                     ...                           ...
# 19970   9308584                     NaN                           NaN
# 19971  10493735                     NaN                           NaN
# 19972  10184754                     NaN                           NaN
# 19973  10446738                     NaN                           NaN
# 19974  10483798  After signing the deed                           NaN
#
#       Neighbourhood or locality  Construction year Building condition
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of              id         Available as of                Available date
# 0      10572904  After signing the deed  September 30 2023 - 12:00 AM  \
# 1      10572903  After signing the deed  September 30 2023 - 12:00 AM
# 2      10572509  After signing the deed      August 6 2023 - 12:00 AM
# 3      10572508  After signing the deed  September 30 2023 - 12:00 AM
# 4      10572922           To be defined                           NaN
# ...         ...                     ...                           ...
# 19970   9308584                     NaN                           NaN
# 19971  10493735                     NaN                           NaN
# 19972  10184754                     NaN                           NaN
# 19973  10446738                     NaN                           NaN
# 19974  10483798  After signing the deed                           NaN
#
#       Neighbourhood or locality  Construction year Building condition
# ...

# %%
df.shape
# Out:
# (19975, 122)
